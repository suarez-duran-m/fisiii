# %%
import matplotlib.pyplot as plt
import math
import numpy as np
import pandas
from xlrd import open_workbook

# %%
wb = open_workbook('test.xls')
#values = []

x = []
y = []

for s in wb.sheets():
    #print 'Sheet:',s.name
    for row in range(1, s.nrows):
        x.append(s.cell(row,0).value)
        y.append(s.cell(row,1).value)
                
#        col_names = s.row(0)
#        col_value = []
#        for name, col in zip(col_names, range(s.ncols)):
#            value  = (s.cell(row,col).value)
            #print(value)
#            try : value = str(int(value))
#            except : pass
#            col_value.append((name.value, value))
#        values.append(col_value)
#print (values)

fig, ax = plt.subplots()

lw = 3.

ax.plot(x,y,'r--',linewidth=lw)#,label='b ~ ')
#ax.plot(t,exp_term, 'b')

#delta_xticks = tf / 10.
#ax.xaxis.set_ticks(np.arange(ti, tf, delta_xticks))

plt.grid(True)
#plt.legend(bbox_to_anchor=(1.1, 1.05),fontsize=24)
plt.rcParams['figure.figsize'] = (20.0, 10.0)

plt.xlabel('Time [s]', fontsize=24)
plt.ylabel('Amplitude [cm]', fontsize=24)

plt.xticks(fontsize = 24)
plt.yticks(fontsize = 24)

plt.show()
